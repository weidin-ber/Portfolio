# %%
import config

# %%
from IPython.display import IFrame

# %%
from time import sleep
from random import randint

# %%
def human():
    for i in range(1):
        wait_time = randint(1,3)
        #print("I will sleep for " + str(wait_time) + " seconds.")
        sleep(wait_time)

# %%
human()

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
import pandas as pd

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
        human()
    return tracks

# %%
tracks_italo_disco=get_playlist_tracks("spotify", "37i9dQZF1DX3jWba5xiDhV")

# %%
tracks_italo_disco
# Out:
# [{'added_at': '2022-10-07T08:10:31Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6czfQ8MjHVmvJKA4LAnviG'},
#       'href': 'https://api.spotify.com/v1/artists/6czfQ8MjHVmvJKA4LAnviG',
#       'id': '6czfQ8MjHVmvJKA4LAnviG',
#       'name': 'Baltimora',
#       'type': 'artist',
#       'uri': 'spotify:artist:6czfQ8MjHVmvJKA4LAnviG'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2AclHzFubT46QrjWFSfkk9'},
#     'href': 'https://api.spotify.com/v1/albums/2AclHzFubT46QrjWFSfkk9',
#     'id': '2AclHzFubT46QrjWFSfkk9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273de82204a5baa683ce85d57cb',
# ...

# %%
features_italo_disco=[]
for item in range(0,75):
    #print (tracks[item]["track"]["id"])
    features_italo_disco.append(sp.audio_features(tracks_italo_disco[item]["track"]["id"])[0])

# %%
df_italo_disco=pd.DataFrame(features_italo_disco)    
df_italo_disco=df_italo_disco[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_italo_disco.head(75)
# Out:
#                         id  danceability  energy  key  loudness  mode  \
# 0   273uCXd7NPrInaiNqtkOrA         0.684   0.573    5   -12.300     1
# 1   2dURQIBrw3XcHyVZlfdpC1         0.824   0.506    5    -7.120     0
# 2   50f0mt35cIwwu3Krk7nS7b         0.868   0.788    1    -4.321     1
# 3   2FHnN5ELL83TGbtXMDzoiJ         0.779   0.635    2    -8.028     0
# 4   3CX1FiiXSbvKjsXRYwApAP         0.926   0.780    4    -6.295     0
# ..                     ...           ...     ...  ...       ...   ...
# 70  2ue8ttSzbhnvhO7zc52NjC         0.789   0.505    1   -12.499     1
# 71  6bKOUB4zXxYFhG4a3x6JGZ         0.710   0.912   11    -6.505     0
# 72  74nFLqYUx40Y2v0ZtFQHI8         0.797   0.841    0    -9.847     1
# 73  4x4Ip4xOCRGIBNsts7GUBD         0.800   0.365   10   -13.592     1
# 74  35FPjkNAkXdp8cXgh6gBfH         0.709   0.879    8   -10.867     1
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_italo_disco.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_italo_disco.csv', index=False, header=True)

# %%
tracks_hip_hop=get_playlist_tracks("spotify", "3RcRK9HGTAm9eLW1LepWKZ")

# %%
features_hip_hop=[]
for item in range(0,233):
    #print (tracks[item]["track"]["id"])
    features_hip_hop.append(sp.audio_features(tracks_hip_hop[item]["track"]["id"])[0])

# %%
df_hip_hop=pd.DataFrame(features_hip_hop)    
df_hip_hop=df_hip_hop[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_hip_hop
# Out:
#                          id  danceability  energy  key  loudness  mode  \
# 0    4675yUu8AUbE72T94BkLCD         0.893   0.740   11    -4.936     0
# 1    7iL6o9tox1zgHpKUfh9vuC         0.899   0.713    6    -2.752     0
# 2    7BMO7O7ImjV8HNTH74Tshv         0.908   0.758    9    -4.753     0
# 3    1bl99Q4umnPomYGv3dQP67         0.663   0.777   11    -4.954     0
# 4    1v7L65Lzy0j0vdpRjJewt1         0.686   0.735    2    -4.616     1
# ..                      ...           ...     ...  ...       ...   ...
# 228  3WgTbafC5uRpdQdFndQYxE         0.857   0.706    7    -3.082     1
# 229  5203pcq3cNteJuOVhIEnt6         0.572   0.572    6    -8.324     1
# 230  34ceTg8ChN5HjrqiIYCn9Q         0.673   0.683    1    -5.693     1
# 231  2VarpyoSpCPNKI56WSAEMN         0.809   0.537    8    -5.807     1
# 232  49FYlytm3dAAraYgpoJZux         0.583   0.829    1    -4.603     1
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_hip_hop.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_hip_hop1.csv', index=False, header=True)

# %%
tracks_hip_hop_b=get_playlist_tracks("spotify", "5DZ93TH6ABgWYRgdBNJs8O")

# %%
features_hip_hop_b=[]
for item in range(0,146):
    #print (tracks[item]["track"]["id"])
    features_hip_hop_b.append(sp.audio_features(tracks_hip_hop_b[item]["track"]["id"])[0])

# %%
df_hip_hop_b=pd.DataFrame(features_hip_hop_b)    
df_hip_hop_b=df_hip_hop_b[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_hip_hop_b
# Out:
#                          id  danceability  energy  key  loudness  mode  \
# 0    1bDbXMyjaUIooNwFE9wn0N         0.561   0.520   11    -9.342     0
# 1    6XO8RlYuJCiI0v3IA48FeJ         0.645   0.525    3    -5.399     0
# 2    74loibzxXRL875X20kenvk         0.695   0.555    5    -8.500     0
# 3    2KLwPaRDOB87XOYAT2fgxh         0.749   0.630    4    -6.652     0
# 4    6mM8gri8d2abYYomjOV4ut         0.586   0.689    0    -6.040     1
# ..                      ...           ...     ...  ...       ...   ...
# 141  3TJTvFCoVZaWWTRuaIPkMl         0.802   0.420    7   -10.088     0
# 142  6Md6lyVVoKWcOaSg8u1tDn         0.798   0.471    8    -8.824     1
# 143  6rI8uFFmGyvS2N6sqDCdu3         0.699   0.580    7    -7.050     0
# 144  2eWHHPZS4pb7mEMcow4bqT         0.751   0.805    3    -5.017     0
# 145  7tirvvM9yib3Z3BgSXUHOi         0.867   0.392   11   -12.090     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_hip_hop_b.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_hip_hop2.csv', index=False, header=True)

# %%
tracks_bossa_nova=get_playlist_tracks("spotify", "089PHs02G5E3K0lYdane1p")

# %%
features_bossa_nova=[]
for item in range(0,38):
    #print (tracks[item]["track"]["id"])
    features_bossa_nova.append(sp.audio_features(tracks_bossa_nova[item]["track"]["id"])[0])

# %%
df_bossa_nova=pd.DataFrame(features_bossa_nova)    
df_bossa_nova=df_bossa_nova[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_bossa_nova
# Out:
#                         id  danceability  energy  key  loudness  mode  \
# 0   209ucYTS6vWEV5iydrHiOt         0.793  0.3720   10   -15.491     1
# 1   5je0CDv1Z1hT82Nek1Fjhl         0.578  0.3640    2   -15.162     1
# 2   0Vl9aGb0dmeiCQ2ATgNK2B         0.592  0.7610    5    -6.432     0
# 3   0r1Ta1ImfdKXJ0iYqdN3uX         0.437  0.2210   11   -20.372     0
# 4   2HgcLPRWFrYEgulCUqgosg         0.726  0.3710    7   -11.088     0
# 5   3QKJELWORZZ7rUZDWeMWSA         0.653  0.3190    4   -17.813     0
# 6   6aMmz0HbtjJnvUMteBO2kc         0.536  0.6470    3    -9.471     1
# 7   36SJ7ZFx8J1f1RsewmUwMX         0.820  0.6340    9   -13.816     1
# 8   204tfkWrfEkzlG6H0iF46C         0.526  0.1290    9   -16.818     0
# 9   37fHxKAICYRDmYaTujdiBl         0.587  0.1320    3   -17.782     1
# 10  15ouqiBsgL12olEwP3COsH         0.654  0.3930    3   -13.392     1
# 11  6MCaOLDl0epJPRN76H5S4N         0.503  0.6220    0    -6.890     1
# ...

# %%
df_bossa_nova.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_bossa_nova.csv', index=False, header=True)

# %%
tracks_synth_pop=get_playlist_tracks("spotify", "37i9dQZF1DWU1f2CQHNexG")
tracks_pop=get_playlist_tracks("spotify", "37i9dQZF1EQncLwOalG3K7")
tracks_rock=get_playlist_tracks("spotify", "37i9dQZF1EQpj7X7UK8OOF")
tracks_rock_classics=get_playlist_tracks("spotify", "37i9dQZF1DWXRqgorJj26U")

# %%
song_list=[]
song_list= tracks_synth_pop + tracks_pop + tracks_rock + tracks_rock_classics

# %%
len(song_list)
# Out:
# 375

# %%
features_synth_pop_rock_rockc=[]
for item in range(0,375):
    #print (tracks[item]["track"]["id"])
    features_synth_pop_rock_rockc.append(sp.audio_features(song_list[item]["track"]["id"])[0])

# %%
df_synth_pop_rock_rockc=pd.DataFrame(features_synth_pop_rock_rockc)    
df_synth_pop_rock_rockc=df_synth_pop_rock_rockc[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_synth_pop_rock_rockc
# Out:
#                          id  danceability  energy  key  loudness  mode  \
# 0    4dk40nfaQav6b4ZsJ9OYUo         0.637   0.850    0    -5.054     1
# 1    5vmRQ3zELMLUQPo2FLQ76x         0.685   0.584    5   -10.616     0
# 2    1TfqLAPs4K3s2rJMoCokcS         0.692   0.711    0    -7.498     0
# 3    0cGG2EouYCEEC3xfa0tDFV         0.500   0.501    0    -8.284     0
# 4    48p5E25cFPanxuwCTmTpuL         0.629   0.876    0   -10.141     1
# ..                      ...           ...     ...  ...       ...   ...
# 370  3KPwt1LBpt1jVSHz8GXERo         0.543   0.529    7    -9.717     1
# 371  3MODES4TNtygekLl146Dxd         0.468   0.607    9   -11.367     1
# 372  5AoZknxgY6F25gAcVahO41         0.668   0.447    2   -11.124     1
# 373  1IqFh00G2kvvMm8pRMpehA         0.430   0.463    2   -10.960     1
# 374  5uvosCdMlFdTXhoazkTI5R         0.413   0.725    3    -5.787     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_synth_pop_rock_rockc.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_synth_pop_rock_rockc.csv', index=False, header=True)

# %%
tracks_reggae=get_playlist_tracks("spotify", "37i9dQZF1EQpjs4F0vUZ1x")
tracks_reggae2=get_playlist_tracks("spotify", "7ctcnSkvchrp7rBhMGUJF8")
tracks_world_music=get_playlist_tracks("spotify", "0q6c4fBoe3XFqkPgHo01KT")
tracks_classic=get_playlist_tracks("spotify", "1h0CEZCm6IbFTbxThn6Xcs")
tracks_kpop=get_playlist_tracks("spotify", "37i9dQZF1EQpesGsmIyqcW")
tracks_disco=get_playlist_tracks("spotify", "37i9dQZF1DX2GKumqRIZ7g")
tracks_country=get_playlist_tracks("spotify", "1mJhSx6aYQmINsZ8dG4gzU")
tracks_ndw=get_playlist_tracks("spotify", "37i9dQZF1DX5w8WNnaxSfQ")
tracks_jazz=get_playlist_tracks("spotify", "37i9dQZF1DXbITWG1ZJKYt")
tracks_dancehall=get_playlist_tracks("spotify", "37i9dQZF1DXan38dNVDdl4")

# %%
song_list1=[]
song_list1= tracks_reggae + tracks_reggae2 + tracks_world_music + tracks_classic + tracks_kpop + tracks_disco + tracks_country + tracks_ndw + tracks_jazz + tracks_dancehall

# %%
len(song_list1)
# Out:
# 1299

# %%
features_reggae_world_classic_more=[]
for item in range(0,1299):
    #print (tracks[item]["track"]["id"])
    features_reggae_world_classic_more.append(sp.audio_features(song_list1[item]["track"]["id"])[0])

# %%
df_reggae_world_classic_more=pd.DataFrame(features_reggae_world_classic_more)    
df_reggae_world_classic_more=df_reggae_world_classic_more[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_reggae_world_classic_more
# Out:
#                           id  danceability  energy  key  loudness  mode  \
# 0     2zKQmG3vaoRpogBihuBb3p         0.789   0.598    6    -6.850     0
# 1     7I1fHMDNlHobS8SBUJAUDt         0.733   0.668    2    -5.300     1
# 2     0kDL2MQeL800pf9LFQGzQv         0.744   0.690   11    -7.541     1
# 3     0dO79bdqpF4yl3Hpms8Eu7         0.795   0.415    0   -10.466     1
# 4     4DQttwipnILl88cru3BRZx         0.824   0.366    7   -10.960     1
# ...                      ...           ...     ...  ...       ...   ...
# 1294  0jHfKDP1LfRrEmazuothw6         0.583   0.794    1    -7.011     1
# 1295  7aBRoWtp9jsZFxwml1LfeG         0.810   0.604    7    -3.296     1
# 1296  35k0jeXz6vwKCasj2cRkSE         0.717   0.504    2    -5.751     1
# 1297  488Uem9ellPhXvA8XfBhty         0.851   0.686    9    -4.297     0
# 1298  3M9SdslKjGgu18LtRPiCBA         0.561   0.688   11    -6.964     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_reggae_world_classic_more.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_rggae_world_classic_more.csv', index=False, header=True)

# %%
tracks_big=get_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")

# %%
features_big=[]
for item in range(0,5295):
    #print (tracks[item]["track"]["id"])
    features_big.append(sp.audio_features(tracks_big[item]["track"]["id"])[0])

# %%
df_features_big=pd.DataFrame(features_big)    
df_features_big=df_features_big[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_features_big
# Out:
#                           id  danceability  energy  key  loudness  mode  \
# 0     3dYD57lRAUcMHufyqn9GcI         0.566   0.664    4    -5.303     0
# 1     2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7    -4.630     0
# 2     7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6    -9.222     1
# 3     4Ub8UsjWuewQrPhuepfVpd         0.679   0.715    9    -6.383     1
# 4     3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10    -5.892     0
# ...                      ...           ...     ...  ...       ...   ...
# 5290  4Zcz6saEkOII3PlXd9gN3o         0.609   0.679    0    -4.545     1
# 5291  6HU7h9RYOaPRFeh0R3UeAr         0.442   0.612    2    -7.222     1
# 5292  5yorXJWdBan1Vlh116ZtQ7         0.897   0.371    1    -5.019     1
# 5293  11ZulcYY4lowvcQm4oe3VJ         0.964   0.398   11    -8.981     0
# 5294  6tDDoYIxWvMLTdKpjFkc1B         0.653   0.524   11    -9.016     0
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_features_big.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_big.csv', index=False, header=True)

# %%
tracks_big2=get_playlist_tracks("spotify", "5S8SJdl1BDc0ugpkEvFsIL")

# %%
features_big2=[]
for item in range(0,2000):
    #print (tracks[item]["track"]["id"])
    features_big2.append(sp.audio_features(tracks_big2[item]["track"]["id"])[0])

# %%
for item in range(2001,4000):
    #print (tracks[item]["track"]["id"])
    features_big2.append(sp.audio_features(tracks_big2[item]["track"]["id"])[0])

# %%
df_features_big2=pd.DataFrame(features_big2)    
df_features_big2=df_features_big2[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_features_big2
# Out:
#                           id  danceability  energy  key  loudness  mode  \
# 0     2yLa0QULdQr0qAIvVwN6B5         0.613   0.764    2    -6.509     1
# 1     4Vxu50qVrQcycjRyJQaZLC         0.687   0.845    7    -4.370     1
# 2     6b8Be6ljOzmkOmFslEb23P         0.818   0.803    1    -4.282     1
# 3     0afhq8XCExXpqazXczTSve         0.624   0.876    9    -3.374     1
# 4     1HNkqx9Ahdgi1Ixy2xkKkL         0.614   0.379    4   -10.480     1
# ...                      ...           ...     ...  ...       ...   ...
# 5779  45YtTdmH2PNKEnxN3uTZQy         0.702   0.226    5   -13.417     1
# 5780  5RLzsVW6UNiV2YrOlKwzNN         0.644   0.156    1   -16.529     1
# 5781  4qQ8sToR3GNossXlwSlyKz         0.680   0.258    9   -11.995     1
# 5782  0RluX0auLYdKAZxWQZpLiG         0.177   0.266    8   -13.568     1
# 5783  3rLLRKNc2HvE4hkMYRe1RE         0.806   0.191    5    -9.527     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_features_big2.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_big2.csv', index=False, header=True)

# %%
df_final=pd.concat([df_italo_disco, df_hip_hop, df_hip_hop_b, df_bossa_nova, df_synth_pop_rock_rockc, df_reggae_world_classic_more, df_features_big, df_features_big2])

# %%
df_final
# Out:
#                           id  danceability  energy  key  loudness  mode  \
# 0     273uCXd7NPrInaiNqtkOrA         0.684   0.573    5   -12.300     1
# 1     2dURQIBrw3XcHyVZlfdpC1         0.824   0.506    5    -7.120     0
# 2     50f0mt35cIwwu3Krk7nS7b         0.868   0.788    1    -4.321     1
# 3     2FHnN5ELL83TGbtXMDzoiJ         0.779   0.635    2    -8.028     0
# 4     3CX1FiiXSbvKjsXRYwApAP         0.926   0.780    4    -6.295     0
# ...                      ...           ...     ...  ...       ...   ...
# 5779  45YtTdmH2PNKEnxN3uTZQy         0.702   0.226    5   -13.417     1
# 5780  5RLzsVW6UNiV2YrOlKwzNN         0.644   0.156    1   -16.529     1
# 5781  4qQ8sToR3GNossXlwSlyKz         0.680   0.258    9   -11.995     1
# 5782  0RluX0auLYdKAZxWQZpLiG         0.177   0.266    8   -13.568     1
# 5783  3rLLRKNc2HvE4hkMYRe1RE         0.806   0.191    5    -9.527     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_final=df_final.drop_duplicates()

# %%
df_final
# Out:
#                           id  danceability  energy  key  loudness  mode  \
# 0     273uCXd7NPrInaiNqtkOrA         0.684   0.573    5   -12.300     1
# 1     2dURQIBrw3XcHyVZlfdpC1         0.824   0.506    5    -7.120     0
# 2     50f0mt35cIwwu3Krk7nS7b         0.868   0.788    1    -4.321     1
# 3     2FHnN5ELL83TGbtXMDzoiJ         0.779   0.635    2    -8.028     0
# 4     3CX1FiiXSbvKjsXRYwApAP         0.926   0.780    4    -6.295     0
# ...                      ...           ...     ...  ...       ...   ...
# 4351  45YtTdmH2PNKEnxN3uTZQy         0.702   0.226    5   -13.417     1
# 4352  5RLzsVW6UNiV2YrOlKwzNN         0.644   0.156    1   -16.529     1
# 4353  4qQ8sToR3GNossXlwSlyKz         0.680   0.258    9   -11.995     1
# 4354  0RluX0auLYdKAZxWQZpLiG         0.177   0.266    8   -13.568     1
# 4355  3rLLRKNc2HvE4hkMYRe1RE         0.806   0.191    5    -9.527     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_final=df_final.set_index('id')

# %%
df_final=df_final.drop_duplicates()

# %%
df_final.reset_index(inplace=True)

# %%
df_final
# Out:
#                            id  danceability  energy  key  loudness  mode  \
# 0      273uCXd7NPrInaiNqtkOrA         0.684   0.573    5   -12.300     1
# 1      2dURQIBrw3XcHyVZlfdpC1         0.824   0.506    5    -7.120     0
# 2      50f0mt35cIwwu3Krk7nS7b         0.868   0.788    1    -4.321     1
# 3      2FHnN5ELL83TGbtXMDzoiJ         0.779   0.635    2    -8.028     0
# 4      3CX1FiiXSbvKjsXRYwApAP         0.926   0.780    4    -6.295     0
# ...                       ...           ...     ...  ...       ...   ...
# 10022  45YtTdmH2PNKEnxN3uTZQy         0.702   0.226    5   -13.417     1
# 10023  5RLzsVW6UNiV2YrOlKwzNN         0.644   0.156    1   -16.529     1
# 10024  4qQ8sToR3GNossXlwSlyKz         0.680   0.258    9   -11.995     1
# 10025  0RluX0auLYdKAZxWQZpLiG         0.177   0.266    8   -13.568     1
# 10026  3rLLRKNc2HvE4hkMYRe1RE         0.806   0.191    5    -9.527     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
df_final.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_final.csv', index=False, header=True)

# %%
tracks_techno=get_playlist_tracks("spotify", "37i9dQZF1DX6J5NfMJS675")
tracks_house=get_playlist_tracks("spotify", "37i9dQZF1DWTU3Zl0elDUa")
tracks_trance=get_playlist_tracks("spotify", "37i9dQZF1DXbtYAdenGE9U")

# %%
techno_list=[]
techno_list= tracks_trance + tracks_house + tracks_techno

# %%
len(techno_list)
# Out:
# 170

# %%
features_techno=[]
for item in range(0,170):
    #print (tracks[item]["track"]["id"])
    features_techno.append(sp.audio_features(techno_list[item]["track"]["id"])[0])

# %%
df_techno=pd.DataFrame(features_techno)    
df_techno=df_techno[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_techno
# Out:
#                          id  danceability  energy  key  loudness  mode  \
# 0    5XVjNRubJUW0iPhhSWpLCj         0.671   0.882    8    -6.149     0
# 1    4wtR6HB3XekEengMX17cpc         0.604   0.755    0   -10.761     1
# 2    1arJHhz6TxMV50SNvSmGnV         0.591   0.888    4    -6.836     1
# 3    7xQYVjs4wZNdCwO0EeAWMC         0.576   0.953   10    -8.968     1
# 4    3e9L9HiHKcfYLAga28Vmcf         0.644   0.981    7    -6.644     0
# ..                      ...           ...     ...  ...       ...   ...
# 165  5Ig2RPAPLrkAkFpyr8uAPj         0.786   0.908    7   -10.402     1
# 166  3mlkpFLHRHmVUho7xJcKit         0.569   0.882    1    -7.489     1
# 167  5VOlgrZaSeoGPAZxOjmHiO         0.639   0.918   11    -8.736     0
# 168  3XZOviqLQTQdVrLlCOH8Ji         0.737   0.990    7    -4.795     1
# 169  7vmXmhia1MFqu8t3IAYOkP         0.542   0.945   11    -4.711     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_techno.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_techno.csv', index=False, header=True)

# %%
tracks_pop=get_playlist_tracks("spotify", "3BxbED9sPDNdodoZ0weTvB")
tracks_pop2=get_playlist_tracks("spotify", "7r82nmf5b9lvnvhnAURXCQ")
tracks_pop3=get_playlist_tracks("spotify", "141guhSLUNzE58MqlIC4zT")
tracks_pop4=get_playlist_tracks("spotify", "48H3QaCWFstYKvCtwq0wY0")
tracks_house1=get_playlist_tracks("spotify", "6iDkINPskeG8X2Mv1uiBdN")
tracks_house2=get_playlist_tracks("spotify", "0v3h3QmLDIiP0lVQK1ASj2")

# %%
pop_list=[]
pop_list= tracks_pop + tracks_pop2 + tracks_pop3 + tracks_pop4 + tracks_house1 + tracks_house2

# %%
len(pop_list)
# Out:
# 579

# %%
features_pop=[]
for item in range(0,579):
    #print (tracks[item]["track"]["id"])
    features_pop.append(sp.audio_features(pop_list[item]["track"]["id"])[0])

# %%
df_pop=pd.DataFrame(features_pop)    
df_pop=df_pop[["id","danceability","energy","key","loudness","mode","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]

# %%
df_pop
# Out:
#                          id  danceability  energy  key  loudness  mode  \
# 0    0V3wPSX9ygBnCm8psDIegu         0.637   0.643    4    -6.571     1
# 1    1bDbXMyjaUIooNwFE9wn0N         0.561   0.520   11    -9.342     0
# 2    4k6Uh1HXdhtusDW5y8Gbvy         0.686   0.494    1    -7.093     1
# 3    3nqQXoyQOWXiESFLlDF1hG         0.714   0.472    2    -7.375     1
# 4    73vIOb4Q7YN6HeJTbscRx5         0.587   0.742    6    -6.640     0
# ..                      ...           ...     ...  ...       ...   ...
# 574  5JAGMln9Bd4xrHkjS4jMf2         0.774   0.834    2    -5.456     1
# 575  0QKfiqpEU4h9ycPSzIFwYe         0.617   0.533    3   -11.516     0
# 576  3BneMfYdo9X8m90BRhMzSL         0.701   0.896   11    -5.738     0
# 577  4kqv0fA0vF1vNwlVQqewdL         0.748   0.990    1    -4.790     1
# 578  0oks4FnzhNp5QPTZtoet7c         0.740   0.682    9   -10.420     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_pop=df_pop.drop_duplicates()

# %%
df_pop
# Out:
#                          id  danceability  energy  key  loudness  mode  \
# 0    0V3wPSX9ygBnCm8psDIegu         0.637   0.643    4    -6.571     1
# 1    1bDbXMyjaUIooNwFE9wn0N         0.561   0.520   11    -9.342     0
# 2    4k6Uh1HXdhtusDW5y8Gbvy         0.686   0.494    1    -7.093     1
# 3    3nqQXoyQOWXiESFLlDF1hG         0.714   0.472    2    -7.375     1
# 4    73vIOb4Q7YN6HeJTbscRx5         0.587   0.742    6    -6.640     0
# ..                      ...           ...     ...  ...       ...   ...
# 573  1xgwRZnFMa0JfV9m0qMAao         0.703   0.737    5   -11.047     0
# 574  5JAGMln9Bd4xrHkjS4jMf2         0.774   0.834    2    -5.456     1
# 576  3BneMfYdo9X8m90BRhMzSL         0.701   0.896   11    -5.738     0
# 577  4kqv0fA0vF1vNwlVQqewdL         0.748   0.990    1    -4.790     1
# 578  0oks4FnzhNp5QPTZtoet7c         0.740   0.682    9   -10.420     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_pop.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_pop_house.csv', index=False, header=True)

# %%
df_orginal = pd.read_csv("export_final.csv")

# %%
df_orginal = pd.concat([df_orginal, df_pop])

# %%
df_orginal
# Out:
#                          id  danceability  energy  key  loudness  mode  \
# 0    273uCXd7NPrInaiNqtkOrA         0.684   0.573    5   -12.300     1
# 1    2dURQIBrw3XcHyVZlfdpC1         0.824   0.506    5    -7.120     0
# 2    50f0mt35cIwwu3Krk7nS7b         0.868   0.788    1    -4.321     1
# 3    2FHnN5ELL83TGbtXMDzoiJ         0.779   0.635    2    -8.028     0
# 4    3CX1FiiXSbvKjsXRYwApAP         0.926   0.780    4    -6.295     0
# ..                      ...           ...     ...  ...       ...   ...
# 573  1xgwRZnFMa0JfV9m0qMAao         0.703   0.737    5   -11.047     0
# 574  5JAGMln9Bd4xrHkjS4jMf2         0.774   0.834    2    -5.456     1
# 576  3BneMfYdo9X8m90BRhMzSL         0.701   0.896   11    -5.738     0
# 577  4kqv0fA0vF1vNwlVQqewdL         0.748   0.990    1    -4.790     1
# 578  0oks4FnzhNp5QPTZtoet7c         0.740   0.682    9   -10.420     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df_final.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_final.csv', index=False, header=True)

# %%
df_orginal.to_csv(r'C:\Users\Lenovo\Documents\GitHub\Ironhack-Labs-Valentin\spotify_project\export_final.csv', index=False, header=True)
