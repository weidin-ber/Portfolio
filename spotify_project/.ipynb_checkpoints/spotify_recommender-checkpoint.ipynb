# %%
import config
from IPython.display import IFrame
from random import randint
import pandas as pd
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import warnings
warnings.filterwarnings('ignore')
import pickle
from tabulate import tabulate

# %%
df_final = pd.read_csv("export_recommender.csv")

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
def load(filename = "filename.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %%
scaler = load("scaler.pickle")
kmeans = load("kmeans_4.pickle")

# %%
#Input User Song
def user_input():
    Input = input("Please enter an artist or song: ")
    results = sp.search(q= Input,limit=3,market="GB")
    global id
    id=results["tracks"]["items"][0]["id"]
    return play_song(id)

# %%
def recommender():
    features = sp.audio_features(id)
    user_df=pd.DataFrame(features)    
    user_df=user_df[["danceability","energy","key", "loudness","acousticness", "valence", "tempo"]]
    user_key = user_df["key"].values
    user_temp = user_df["tempo"].values
    user_scaled = scaler.transform(user_df)
    user_clusters = kmeans.predict(user_scaled)
    recommendation_df = df_final[df_final["cluster"]==user_clusters[0]] 
    record1_df = recommendation_df[recommendation_df["key"]==user_key[0]]
    record_df = record1_df[record1_df["tempo"].between(user_temp[0]-10, user_temp[0]+10)].sample(n=1)
    printed_r_df=record_df[["danceability","energy","key", "loudness","acousticness", "valence", "tempo"]]
    r_id = record_df["id"].values
    print("These are the features of the song you choose: ")
    print(tabulate(user_df, headers='keys', tablefmt='psql'))
    print("These are the features of my recommendation: ")
    print(tabulate(printed_r_df, headers="keys", tablefmt='psql'))
    print("__________________________________________________________________")
    print("This is the song I recommend to you, best regards your friendly AI: ")
    return play_song(r_id[0])

# %%
user_input()
# Out:
# Please enter an artist or song: still dre
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/503OTo2dSqe7qk76rgsbep?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
recommender()
# Out:
# These are the features of the song you choose:
# +----+----------------+----------+-------+------------+----------------+-----------+---------+
# |    |   danceability |   energy |   key |   loudness |   acousticness |   valence |   tempo |
# |----+----------------+----------+-------+------------+----------------+-----------+---------|
# |  0 |          0.816 |    0.775 |    11 |     -3.323 |           0.16 |     0.527 |  93.431 |
# +----+----------------+----------+-------+------------+----------------+-----------+---------+
# These are the features of my recommendation:
# +------+----------------+----------+-------+------------+----------------+-----------+---------+
# |      |   danceability |   energy |   key |   loudness |   acousticness |   valence |   tempo |
# |------+----------------+----------+-------+------------+----------------+-----------+---------|
# | 3412 |          0.884 |    0.826 |    11 |     -3.672 |          0.222 |     0.465 |  94.997 |
# +------+----------------+----------+-------+------------+----------------+-----------+---------+
# __________________________________________________________________
# This is the song I recommend to you, best regards your friendly AI:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/7fPyCCiXVwbzPQ1MtoUChl?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
    features = sp.audio_features(id)
    user_df=pd.DataFrame(features)    
    user_df=user_df[["danceability","energy","key", "loudness","acousticness", "valence", "tempo"]]
    user_key = user_df["key"].values
    user_temp = user_df["tempo"].values
    user_scaled = scaler.transform(user_df)
    user_clusters = kmeans.predict(user_scaled)
    recommendation_df = df_final[df_final["cluster"]==user_clusters[0]] 
    record1_df = recommendation_df[recommendation_df["key"]==user_key[0]]
    record_df = record1_df[record1_df["tempo"].between(user_temp[0]-10, user_temp[0]+10)]
record_df
# Out:
#                            id  danceability  energy  key  loudness  \
# 57     503OTo2dSqe7qk76rgsbep         0.816   0.775   11    -3.323
# 916    1jwi2hdepSbFkuBjOore8i         0.778   0.682   11    -8.171
# 1708   3ejAkJLWQSEJDqDXxK3efB         0.692   0.881   11    -2.563
# 1750   6NEoeBLQbOMw92qMeLfI40         0.818   0.723   11    -4.820
# 3412   7fPyCCiXVwbzPQ1MtoUChl         0.884   0.826   11    -3.672
# 5166   36W3cbAruouTDpcy4nelv4         0.701   0.689   11    -5.764
# 5904   78MLMKaMyZvRUKUyVhyRi0         0.779   0.767   11    -5.462
# 6244   0KrCQlHyTyvG7cw1Ob336w         0.777   0.685   11    -5.837
# 8981   0sbtER6km0p7hxOUvXnXNl         0.714   0.598   11    -6.092
# 9270   073wmqmf5KfrQiNukyuqrq         0.658   0.729   11    -4.090
# 9316   6WQyaRxqf332knjOMWUMQf         0.765   0.657   11    -6.394
# 10560  6vt0I1cw1YmAIKDJvHVIM5         0.795   0.596   11    -3.799
#
#        acousticness  valence    tempo  cluster
# 57          0.16000    0.527   93.431       24
# 916         0.09020    0.604   94.950       24
# 1708        0.04570    0.432  103.053       24
# 1750        0.00561    0.607  102.945       24
# 3412        0.22200    0.465   94.997       24
# 5166        0.06240    0.600   98.993       24
# 5904        0.00214    0.523   91.981       24
# 6244        0.00786    0.535  100.050       24
# 8981        0.01090    0.643   99.563       24
# 9270        0.05910    0.563  102.898       24
# 9316        0.01750    0.553   91.998       24
# 10560       0.10300    0.357  101.985       24
