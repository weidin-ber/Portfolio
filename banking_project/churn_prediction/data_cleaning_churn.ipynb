# %%
import pandas as pd
import numpy as np

# %%
# Load the data as DF
data = pd.read_csv("data/Churn_Modelling.csv")

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# Check data types
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
# Drop na values
data.dropna(inplace=True)

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# Check the proportion of Target 1 and 0
data['Exited'].value_counts(normalize=True)
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %%
data['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
data["Geography"].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
# Get dummies for Geography an Gender
data = pd.get_dummies(data, columns=["Geography", "Gender"], prefix= "dmy",drop_first = True)

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602   Hargrave          619   42       2       0.00
# 1             2    15647311       Hill          608   41       1   83807.86
# 2             3    15619304       Onio          502   42       8  159660.80
# 3             4    15701354       Boni          699   39       1       0.00
# 4             5    15737888   Mitchell          850   43       2  125510.82
# ...         ...         ...        ...          ...  ...     ...        ...
# 9995       9996    15606229   Obijiaku          771   39       5       0.00
# 9996       9997    15569892  Johnstone          516   35      10   57369.61
# 9997       9998    15584532        Liu          709   36       7       0.00
# 9998       9999    15682355  Sabbatini          772   42       3   75075.31
# 9999      10000    15628319     Walker          792   28       4  130142.79
#
# ...

# %%
# Convert customerID to index and drop Rownumber and Surname
data=data.set_index('CustomerId')
data = data.drop("RowNumber", axis=1)
data = data.drop("Surname", axis=1)

# %%
data
# Out:
#             CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# CustomerId
# 15634602            619   42       2       0.00              1          1
# 15647311            608   41       1   83807.86              1          0
# 15619304            502   42       8  159660.80              3          1
# 15701354            699   39       1       0.00              2          0
# 15737888            850   43       2  125510.82              1          1
# ...                 ...  ...     ...        ...            ...        ...
# 15606229            771   39       5       0.00              2          1
# 15569892            516   35      10   57369.61              1          1
# 15584532            709   36       7       0.00              1          0
# 15682355            772   42       3   75075.31              2          1
# 15628319            792   28       4  130142.79              1          1
#
# ...

# %%
# Export dataframe as csv file
data.to_csv(r'C:\Users\Lenovo\Documents\GitHub\final_project_bankchurn\data\data_cleaned.csv', index=False, header=True)
